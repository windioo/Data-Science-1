# %%
import numpy as np 
import pandas as pd

# %%
df1 = pd.read_csv('C:/Users/ASUS/bikeshare2018/bikeshare2018/Bike Share Toronto Ridership_Q1 2018.csv')
q1_2018 = df1.copy()

# %%
route_station = np.where(q1_2018['from_station_id'] == q1_2018['to_station_id'], 'Init point', 'different point')
route_station
# Out:
# array(['different point', 'different point', 'different point', ...,
#        'different point', 'different point', 'different point'],
#       dtype='<U15')

# %%
q1_2018['Return point'] = route_station

# %%
q1_2018
# Out:
#         trip_id  trip_duration_seconds  from_station_id  trip_start_time  \
# 0       2383648                    393             7018    1/1/2018 0:47
# 1       2383649                    625             7184    1/1/2018 0:52
# 2       2383650                    233             7235    1/1/2018 0:55
# 3       2383651                   1138             7202    1/1/2018 0:57
# 4       2383652                    703             7004    1/1/2018 1:00
# ...         ...                    ...              ...              ...
# 178554  2605019                    746             7017  3/31/2018 23:48
# 178555  2605020                    803             7009  3/31/2018 23:51
# 178556  2605021                    411             7062  3/31/2018 23:54
# 178557  2605022                    164             7002  3/31/2018 23:54
# 178558  2605023                   1134             7029  3/31/2018 23:55
#
#                               from_station_name   trip_stop_time  \
# ...

# %%
return_point = q1_2018['Return point'].value_counts() 
return_point
# Out:
# different point    176260
# Init point           2299
# Name: Return point, dtype: int64

# %%
All_bike = q1_2018['Return point'].count()
Init_bike = return_point['Init point']
bike_returned = (Init_bike/All_bike)*100
print('Percentage of Q1 2018 is %.2f' %bike_returned, '%' )
# Out:
# Percentage of Q1 2018 is 1.29 %

# %%
df1 = pd.read_csv('C:/Users/ASUS/bikeshare2018/bikeshare2018/Bike Share Toronto Ridership_Q1 2018.csv')
q1_2018 = df1.copy()
df2 = pd.read_csv('C:/Users/ASUS/bikeshare2018/bikeshare2018/Bike Share Toronto Ridership_Q2 2018.csv')
q2_2018 = df2.copy()
df3 = pd.read_csv('C:/Users/ASUS/bikeshare2018/bikeshare2018/Bike Share Toronto Ridership_Q3 2018.csv')
q3_2018 = df3.copy()
df4 = pd.read_csv('C:/Users/ASUS/bikeshare2018/bikeshare2018/Bike Share Toronto Ridership_Q4 2018.csv')
q4_2018 = df4.copy()

# %%
route_station1 = np.where(q1_2018['from_station_id'] == q1_2018['to_station_id'], 'Init point', 'different point')
route_station2 = np.where(q2_2018['from_station_id'] == q2_2018['to_station_id'], 'Init point', 'different point')
route_station3 = np.where(q3_2018['from_station_id'] == q3_2018['to_station_id'], 'Init point', 'different point')
route_station4 = np.where(q4_2018['from_station_id'] == q4_2018['to_station_id'], 'Init point', 'different point')

# %%
q1_2018['Return point'] = route_station1
q2_2018['Return point'] = route_station2
q3_2018['Return point'] = route_station3
q4_2018['Return point'] = route_station4

# %%
q1_2018
# Out:
#         trip_id  trip_duration_seconds  from_station_id  trip_start_time  \
# 0       2383648                    393             7018    1/1/2018 0:47
# 1       2383649                    625             7184    1/1/2018 0:52
# 2       2383650                    233             7235    1/1/2018 0:55
# 3       2383651                   1138             7202    1/1/2018 0:57
# 4       2383652                    703             7004    1/1/2018 1:00
# ...         ...                    ...              ...              ...
# 178554  2605019                    746             7017  3/31/2018 23:48
# 178555  2605020                    803             7009  3/31/2018 23:51
# 178556  2605021                    411             7062  3/31/2018 23:54
# 178557  2605022                    164             7002  3/31/2018 23:54
# 178558  2605023                   1134             7029  3/31/2018 23:55
#
#                               from_station_name   trip_stop_time  \
# ...

# %%
q2_2018
# Out:
#         trip_id  trip_duration_seconds  from_station_id  trip_start_time  \
# 0       2605025                   1666             7000    4/1/2018 0:01
# 1       2605024                    247             7051    4/1/2018 0:01
# 2       2605026                   2032             7062    4/1/2018 0:03
# 3       2605027                    531             7063    4/1/2018 0:03
# 4       2605028                    642             7199    4/1/2018 0:05
# ...         ...                    ...              ...              ...
# 558365  3244394                   7224             7317  6/30/2018 23:58
# 558366  3244392                   1560             7107  6/30/2018 23:58
# 558367  3244393                   1144             7152  6/30/2018 23:58
# 558368  3244391                    248             7235  6/30/2018 23:58
# 558369  3244395                   1075             7107  6/30/2018 23:59
#
#                               from_station_name trip_stop_time  to_station_id  \
# ...

# %%
return_point_concat= pd.concat([q1_2018, q2_2018, q3_2018, q4_2018])
return_point_concat
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-71213b59531c> in <module>
# ----> 1 return_point_concat= pd.concat([q1_2018, q2_2018, q3_2018, q4_2018])
#       2 return_point_concat
#
# NameError: name 'q1_2018' is not defined
