# %% [markdown]
# # Titanic: Machine Learning from Disaster

# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import statsmodels.api as sm
from sklearn import metrics
from sklearn import preprocessing
from sklearn import svm
from sklearn.metrics import classification_report
from sklearn.cluster import DBSCAN
from sklearn.cluster import KMeans
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# ## Read The Data

# %%
df_titanic = pd.read_csv('train.csv')

# %%
df_titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## Question 1

# %% [markdown]
# Bagaimana  sebaran Fare untuk penumpang selamat dan tidak di kapal Titanic? (dengan statistik deskriptif)

# %% [markdown]
# ### Preprocessing Data

# %%
df_titanic1 = df_titanic

# %% [markdown]
# ### Statistic Descriptive

# %%
plt.figure(figsize=(13, 5))

plt.subplot(1,2,1)
sns.distplot(df_titanic1.loc[df_titanic1['Survived'] == 0]['Fare'])
plt.legend(['Survived'])
plt.title('Fare Distribution in Survived')

plt.subplot(1,2,2)
sns.boxplot(df_titanic1.loc[df_titanic1['Survived'] == 0]['Fare'])
plt.ylabel('Survived')
plt.title('Fare Distribution in Survived')

plt.show()

# %%
df_titanic1.loc[df_titanic1['Survived'] == 0]['Fare'].describe()
# Out:
# count    549.000000
# mean      22.117887
# std       31.388207
# min        0.000000
# 25%        7.854200
# 50%       10.500000
# 75%       26.000000
# max      263.000000
# Name: Fare, dtype: float64

# %%
plt.figure(figsize=(13, 5))

plt.subplot(1,2,1)
sns.distplot(df_titanic1.loc[df_titanic1['Survived'] == 1]['Fare'])
plt.legend(['Not Survived'])
plt.title('Fare Distribution in Survived')

plt.subplot(1,2,2)
sns.boxplot(df_titanic1.loc[df_titanic1['Survived'] == 1]['Fare'])
plt.ylabel('Not Survived')
plt.title('Fare Distribution in Survived')

plt.show()

# %%
df_titanic1.loc[df_titanic1['Survived'] == 1]['Fare'].describe()
# Out:
# count    342.000000
# mean      48.395408
# std       66.596998
# min        0.000000
# 25%       12.475000
# 50%       26.000000
# 75%       57.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
plt.figure(figsize=(13, 5))

plt.subplot(1,2,1)
sns.distplot(df_titanic1.loc[df_titanic1['Survived'] == 0]['Fare'])
sns.distplot(df_titanic1.loc[df_titanic1['Survived'] == 1]['Fare'])
plt.legend(['Not Survived','Survived'])
plt.title('Fare Distribution in Survived State')

plt.subplot(1,2,2)
sns.boxplot(x = df_titanic1['Survived'], y = df_titanic1['Fare'])
plt.xticks([0,1],['Not Survived','Survived'])
plt.title('Fare Distribution in Survived State')

plt.show()

# %% [markdown]
# ## Question 2

# %% [markdown]
# Prediksi berapa umur (Age) penumpang Titanic yang tidak diketahui? (dengan prediktif analitik, regresi)

# %% [markdown]
# ### Preprocessing data

# %%
df_titanic2 = df_titanic

# %% [markdown]
# #### Drop PassengerId, Ticket, and Cabin

# %%
df_titanic2 = df_titanic2.drop(columns = ['PassengerId','Ticket','Cabin'])

# %% [markdown]
# #### Replace NaN In Embarked

# %%
modus_embarked = df_titanic2['Embarked'].value_counts().idxmax()
df_titanic2['Embarked'].replace(np.nan, modus_embarked, inplace=True)

# %% [markdown]
# #### Make Dummy Variabel for Sex And Drop Attribute Sex

# %%
dummy_variable_1 = pd.get_dummies(df_titanic2['Sex'])
dummy_variable_1.rename(columns={'female':'Sex-Female', 'male':'Sex-Male'}, inplace=True)
df_titanic2 = pd.concat([df_titanic2, dummy_variable_1], axis=1)

# %%
df_titanic2 = df_titanic2.drop(columns = ['Sex'])

# %% [markdown]
# #### Make Dummy Variabel for Embarked And Drop Attribute Embarked

# %%
dummy_variable_2 = pd.get_dummies(df_titanic2['Embarked'])
dummy_variable_2.rename(columns={'C':'Embarked-C', 'Q':'Embarked-Q','S':'Embarked-S'}, inplace=True)
df_titanic2 = pd.concat([df_titanic2, dummy_variable_2], axis=1)

# %%
df_titanic2 = df_titanic2.drop(columns = ['Embarked'])

# %% [markdown]
# #### Adding Attribute Squared

# %%
df_titanic2['Pclass2'] = df_titanic2['Pclass']**2
df_titanic2['SibSp2'] = df_titanic2['SibSp']**2
df_titanic2['Parch2'] = df_titanic2['Parch']**2
df_titanic2['SibSp2'] = df_titanic2['SibSp']**2
df_titanic2['Fare2'] = df_titanic2['Fare']**2

# %% [markdown]
# #### Drop Nan In Age for Feature Set

# %%
df_titanic2a = df_titanic2.loc[~df_titanic2['Age'].isnull()]

# %% [markdown]
# #### Check Correlation

# %%
def pair_plot(df, col):
    pp = sns.pairplot(data=df,
                 palette='colorblind',
                 y_vars=['Age'],
                 x_vars=[col],
                 )
    pp.fig.set_size_inches(15,10)
    plt.show()

# %%
target_cols = ['Survived', 'Pclass', 'SibSp', 'Parch', 'Fare', 'Sex-Female', 
               'Sex-Male', 'Embarked-C', 'Embarked-Q', 'Embarked-S', 'Pclass2',
               'SibSp2', 'Parch2', 'Fare2']
for c in target_cols:
    print('Pair Plot of {} with target'.format(c))
    pair_plot(df_titanic2a, c)
    print('='*110)
# Out:
# Pair Plot of Survived with target
# ==============================================================================================================
# Pair Plot of Pclass with target
# ==============================================================================================================
# Pair Plot of SibSp with target
# ==============================================================================================================
# Pair Plot of Parch with target
# ==============================================================================================================
# Pair Plot of Fare with target
# ==============================================================================================================
# Pair Plot of Sex-Female with target
# ==============================================================================================================
# Pair Plot of Sex-Male with target
# ==============================================================================================================
# Pair Plot of Embarked-C with target
# ==============================================================================================================
# Pair Plot of Embarked-Q with target
# ==============================================================================================================
# Pair Plot of Embarked-S with target
# ==============================================================================================================
# Pair Plot of Pclass2 with target
# ==============================================================================================================
# Pair Plot of SibSp2 with target
# ==============================================================================================================
# Pair Plot of Parch2 with target
# ==============================================================================================================
# Pair Plot of Fare2 with target
# ==============================================================================================================

# %%
df_titanic2a.corr(method='pearson').style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# Out:
# <style  type="text/css" >
#     #T_da3898ae_15c6_11eb_b46a_b06ebf20b540row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_da3898ae_15c6_11eb_b46a_b06ebf20b540row0_col1 {
#             background-color:  #5e7de7;
#             color:  #000000;
#         }    #T_da3898ae_15c6_11eb_b46a_b06ebf20b540row0_col2 {
#             background-color:  #9ebeff;
#             color:  #000000;
#         }    #T_da3898ae_15c6_11eb_b46a_b06ebf20b540row0_col3 {
#             background-color:  #abc8fd;
#             color:  #000000;
#         }    #T_da3898ae_15c6_11eb_b46a_b06ebf20b540row0_col4 {
#             background-color:  #c4d5f3;
#             color:  #000000;
#         }    #T_da3898ae_15c6_11eb_b46a_b06ebf20b540row0_col5 {
#             background-color:  #e3d9d3;
#             color:  #000000;
#         }    #T_da3898ae_15c6_11eb_b46a_b06ebf20b540row0_col6 {
#             background-color:  #f7ac8e;
#             color:  #000000;
#         }    #T_da3898ae_15c6_11eb_b46a_b06ebf20b540row0_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_da3898ae_15c6_11eb_b46a_b06ebf20b540row0_col8 {
#             background-color:  #d6dce4;
#             color:  #000000;
#         }    #T_da3898ae_15c6_11eb_b46a_b06ebf20b540row0_col9 {
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }    #T_da3898ae_15c6_11eb_b46a_b06ebf20b540row0_col10 {
#             background-color:  #8caffe;
#             color:  #000000;
#         }    #T_da3898ae_15c6_11eb_b46a_b06ebf20b540row0_col11 {
#             background-color:  #5e7de7;
#             color:  #000000;
#         }    #T_da3898ae_15c6_11eb_b46a_b06ebf20b540row0_col12 {
#             background-color:  #9dbdff;
#             color:  #000000;
#         }    #T_da3898ae_15c6_11eb_b46a_b06ebf20b540row0_col13 {
#             background-color:  #b1cbfc;
#             color:  #000000;
#         }    #T_da3898ae_15c6_11eb_b46a_b06ebf20b540row0_col14 {
#             background-color:  #cfdaea;
#             color:  #000000;
#         }    #T_da3898ae_15c6_11eb_b46a_b06ebf20b540row1_col0 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_da3898ae_15c6_11eb_b46a_b06ebf20b540row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_da3898ae_15c6_11eb_b46a_b06ebf20b540row1_col2 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_da3898ae_15c6_11eb_b46a_b06ebf20b540row1_col3 {
#             background-color:  #c0d4f5;
#             color:  #000000;
#         }    #T_da3898ae_15c6_11eb_b46a_b06ebf20b540row1_col4 {
#             background-color:  #b7cff9;
#             color:  #000000;
#         }    #T_da3898ae_15c6_11eb_b46a_b06ebf20b540row1_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_da3898ae_15c6_11eb_b46a_b06ebf20b540row1_col6 {
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }    #T_da3898ae_15c6_11eb_b46a_b06ebf20b540row1_col7 {
#             background-color:  #d1dae9;
#             color:  #000000;
#         }    #T_da3898ae_15c6_11eb_b46a_b06ebf20b540row1_col8 {
#             background-color:  #7396f5;
#             color:  #000000;
#         }    #T_da3898ae_15c6_11eb_b46a_b06ebf20b540row1_col9 {
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }    #T_da3898ae_15c6_11eb_b46a_b06ebf20b540row1_col10 {
#             background-color:  #d8dce2;
#             color:  #000000;
#         }    #T_da3898ae_15c6_11eb_b46a_b06ebf20b540row1_col11 {
#             background-color:  #b50927;
#             color:  #f1f1f1;
#         }    #T_da3898ae_15c6_11eb_b46a_b06ebf20b540row1_col12 {
#             background-color:  #cedaeb;
#             color:  #000000;
#         }    #T_da3898ae_15c6_11eb_b46a_b06ebf20b540row1_col13 {
#             background-color:  #c0d4f5;
#             color:  #000000;
#         }    #T_da3898ae_15c6_11eb_b46a_b06ebf20b540row1_col14 {
#             background-color:  #7295f4;
#             color:  #000000;
#         }    #T_da3898ae_15c6_11eb_b46a_b06ebf20b540row2_col0 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_da3898ae_15c6_11eb_b46a_b06ebf20b540row2_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_da3898ae_15c6_11eb_b46a_b06ebf20b540row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_da3898ae_15c6_11eb_b46a_b06ebf20b540row2_col3 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_da3898ae_15c6_11eb_b46a_b06ebf20b540row2_col4 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_da3898ae_15c6_11eb_b46a_b06ebf20b540row2_col5 {
#             background-color:  #abc8fd;
#             color:  #000000;
#         }    #T_da3898ae_15c6_11eb_b46a_b06ebf20b540row2_col6 {
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }    #T_da3898ae_15c6_11eb_b46a_b06ebf20b540row2_col7 {
#             background-color:  #abc8fd;
#             color:  #000000;
#         }    #T_da3898ae_15c6_11eb_b46a_b06ebf20b540row2_col8 {
#             background-color:  #9dbdff;
#             color:  #000000;
#         }    #T_da3898ae_15c6_11eb_b46a_b06ebf20b540row2_col9 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_da3898ae_15c6_11eb_b46a_b06ebf20b540row2_col10 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_da3898ae_15c6_11eb_b46a_b06ebf20b540row2_col11 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_da3898ae_15c6_11eb_b46a_b06ebf20b540row2_col12 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_da3898ae_15c6_11eb_b46a_b06ebf20b540row2_col13 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_da3898ae_15c6_11eb_b46a_b06ebf20b540row2_col14 {
#             background-color:  #9fbfff;
#             color:  #000000;
#         }    #T_da3898ae_15c6_11eb_b46a_b06ebf20b540row3_col0 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_da3898ae_15c6_11eb_b46a_b06ebf20b540row3_col1 {
#             background-color:  #9abbff;
#             color:  #000000;
#         }    #T_da3898ae_15c6_11eb_b46a_b06ebf20b540row3_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_da3898ae_15c6_11eb_b46a_b06ebf20b540row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_da3898ae_15c6_11eb_b46a_b06ebf20b540row3_col4 {
#             background-color:  #e4d9d2;
#             color:  #000000;
#         }    #T_da3898ae_15c6_11eb_b46a_b06ebf20b540row3_col5 {
#             background-color:  #adc9fd;
#             color:  #000000;
#         }    #T_da3898ae_15c6_11eb_b46a_b06ebf20b540row3_col6 {
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }    #T_da3898ae_15c6_11eb_b46a_b06ebf20b540row3_col7 {
#             background-color:  #6b8df0;
#             color:  #000000;
#         }    #T_da3898ae_15c6_11eb_b46a_b06ebf20b540row3_col8 {
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }    #T_da3898ae_15c6_11eb_b46a_b06ebf20b540row3_col9 {
#             background-color:  #96b7ff;
#             color:  #000000;
#         }    #T_da3898ae_15c6_11eb_b46a_b06ebf20b540row3_col10 {
#             background-color:  #8caffe;
#             color:  #000000;
#         }    #T_da3898ae_15c6_11eb_b46a_b06ebf20b540row3_col11 {
#             background-color:  #9bbcff;
#             color:  #000000;
#         }    #T_da3898ae_15c6_11eb_b46a_b06ebf20b540row3_col12 {
#             background-color:  #cc403a;
#             color:  #f1f1f1;
#         }    #T_da3898ae_15c6_11eb_b46a_b06ebf20b540row3_col13 {
#             background-color:  #bed2f6;
#             color:  #000000;
#         }    #T_da3898ae_15c6_11eb_b46a_b06ebf20b540row3_col14 {
#             background-color:  #90b2fe;

# %% [markdown]
# ### Regression Modelling

# %%
df_titanic2b = df_titanic2.loc[df_titanic2['Age'].isnull()] # for prediction

# %% [markdown]
# #### Multi Linear Regression

# %%
features = ['Survived', 'Pclass', 'SibSp', 'Parch', 'Fare', 'Sex-Female',
            'Sex-Male', 'Embarked-C', 'Embarked-Q', 'Embarked-S']
X = df_titanic2a[features]
y = df_titanic2a['Age']

# %%
X = sm.add_constant(X)
model = sm.OLS(y, X)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    Age   R-squared:                       0.275
# Model:                            OLS   Adj. R-squared:                  0.266
# Method:                 Least Squares   F-statistic:                     33.36
# Date:                Sat, 24 Oct 2020   Prob (F-statistic):           1.14e-44
# Time:                        14:03:12   Log-Likelihood:                -2808.7
# No. Observations:                 714   AIC:                             5635.
# Df Residuals:                     705   BIC:                             5676.
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         29.5617      1.211     24.416      0.000      27.185      31.939
# Survived      -6.7695      1.201     -5.639      0.000      -9.126      -4.412
# Pclass        -8.2088      0.716    -11.465      0.000      -9.614      -6.803
# SibSp         -4.0668      0.550     -7.389      0.000      -5.147      -2.986
# Parch         -0.8268      0.619     -1.335      0.182      -2.043       0.389
# Fare          -0.0122      0.011     -1.077      0.282      -0.034       0.010
# Sex-Female    14.8952      0.936     15.912      0.000      13.057      16.733
# Sex-Male      14.6665      0.748     19.614      0.000      13.198      16.135
# Embarked-C     7.8209      1.127      6.938      0.000       5.608      10.034
# Embarked-Q    12.1615      1.837      6.620      0.000       8.554      15.769
# Embarked-S     9.5793      0.874     10.966      0.000       7.864      11.294
# ==============================================================================
# Omnibus:                       21.453   Durbin-Watson:                   1.892
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               22.565
# Skew:                           0.423   Prob(JB):                     1.26e-05
# Kurtosis:                       3.209   Cond. No.                     4.08e+17
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.72e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
Xtest = np.array(df_titanic2b[features])
Xtest = sm.add_constant(Xtest)

# %%
ypred = results.predict(Xtest)

# %% [markdown]
# #### Multi Polynominal Regression

# %%
features2 = ['Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'Sex-Female',
            'Sex-Male', 'Embarked-C', 'Embarked-Q', 'Embarked-S', 'Pclass2',
            'SibSp2', 'Parch2', 'Fare2']
X2 = df_titanic2a[features2]
y2 = df_titanic2a['Age']

# %%
X2 = sm.add_constant(X2)
model2 = sm.OLS(y2, X2)
results2 = model2.fit()
print(results2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    Age   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 5.780e+30
# Date:                Sat, 24 Oct 2020   Prob (F-statistic):               0.00
# Time:                        14:03:50   Log-Likelihood:                 20941.
# No. Observations:                 714   AIC:                        -4.185e+04
# Df Residuals:                     700   BIC:                        -4.179e+04
# Df Model:                          13
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       6.217e-15   1.22e-14      0.511      0.610   -1.77e-14    3.01e-14
# Survived    1.021e-14   4.45e-15      2.297      0.022    1.48e-15    1.89e-14
# Pclass      -1.51e-14   1.94e-14     -0.777      0.437   -5.32e-14     2.3e-14
# Age            1.0000    1.4e-16   7.12e+15      0.000       1.000       1.000
# SibSp      -3.109e-15   4.69e-15     -0.663      0.508   -1.23e-14     6.1e-15
# Parch      -1.332e-15   4.91e-15     -0.271      0.786    -1.1e-14    8.31e-15
# Fare       -2.082e-16   1.06e-16     -1.971      0.049   -4.16e-16   -8.07e-19
# Sex-Female  3.109e-15   6.81e-15      0.457      0.648   -1.03e-14    1.65e-14
# Sex-Male    2.665e-15   6.08e-15      0.438      0.662   -9.28e-15    1.46e-14
# Embarked-C -5.773e-15   5.35e-15     -1.079      0.281   -1.63e-14    4.73e-15
# Embarked-Q  4.885e-15   7.64e-15      0.639      0.523   -1.01e-14    1.99e-14
# Embarked-S  5.773e-15    5.2e-15      1.111      0.267   -4.43e-15     1.6e-14
# Pclass2     5.107e-15   4.44e-15      1.149      0.251   -3.62e-15    1.38e-14
# SibSp2      7.772e-16   1.25e-15      0.624      0.533   -1.67e-15    3.22e-15
# Parch2      6.661e-16   1.29e-15      0.518      0.605   -1.86e-15    3.19e-15
# Fare2      -1.653e-18   2.36e-19     -7.020      0.000   -2.12e-18   -1.19e-18
# ==============================================================================
# Omnibus:                     1060.741   Durbin-Watson:                   1.960
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           264621.557
# Skew:                           8.403   Prob(JB):                         0.00
# Kurtosis:                      95.803   Cond. No.                     3.58e+20
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.12e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
Xtest2 = df_titanic2b[features2]
Xtest2 = sm.add_constant(Xtest2)

# %%
ypred2 = results2.predict(Xtest2)

# %% [markdown]
# #### Result

# %%
df_titanic2b = df_titanic2b.reset_index(drop = True)

# %%
df_titanic2b['Age_pred'] = pd.DataFrame(ypred)
df_titanic2b['Age_pred2'] = pd.DataFrame(ypred2)

# %%
df_titanic2b[['Name','Age_pred','Age_pred2']]
# Out:
#                                          Name   Age_pred  Age_pred2
# 0                            Moran, Mr. James  31.660452        NaN
# 1                Williams, Mr. Charles Eugene  30.462362        NaN
# 2                     Masselmani, Mrs. Fatima  20.794150        NaN
# 3                     Emir, Mr. Farred Chehab  27.334866        NaN
# 4               O'Dwyer, Miss. Ellen "Nellie"  25.126774        NaN
# ..                                        ...        ...        ...
# 172                          Razi, Mr. Raihed  27.334815        NaN
# 173         Sage, Miss. Dorothy Edith "Dolly"  -5.623419        NaN
# 174               van Melkebeke, Mr. Philemon  29.065587        NaN
# 175                        Laleff, Mr. Kristo  29.085084        NaN
# 176  Johnston, Miss. Catherine Helen "Carrie"  23.404478        NaN
#
# [177 rows x 3 columns]

# %% [markdown]
# ## Question 3

# %% [markdown]
# Dengan menggunakan prediktif analitik klasifikasi, berapa persentase keselamatan (Survived) penumpang  Titanic? (dengan prediktif analitik, klasifikasi)

# %% [markdown]
# ### Data preprocessing

# %%
df_titanic3 = df_titanic

# %% [markdown]
# #### Drop PassengerId, Name, Ticket, and Cabin

# %%
df_titanic3 = df_titanic3.drop(columns = ['PassengerId','Name','Ticket','Cabin'])

# %% [markdown]
# #### Replace NaN In Age

# %%
avg_age = df_titanic3['Age'].astype('float').mean()
df_titanic3['Age'].replace(np.nan, avg_age, inplace=True)

# %% [markdown]
# #### Replace NaN In Embarked

# %%
modus_embarked = df_titanic3['Embarked'].value_counts().idxmax()
df_titanic3['Embarked'].replace(np.nan, modus_embarked, inplace=True)

# %% [markdown]
# #### Make Dummy Variabel for Sex And Drop Attribute Sex

# %%
dummy_variable_1 = pd.get_dummies(df_titanic3['Sex'])
dummy_variable_1.rename(columns={'female':'Sex-female', 'male':'Sex-male'}, inplace=True)
df_titanic3 = pd.concat([df_titanic3, dummy_variable_1], axis=1)
df_titanic3 = df_titanic3.drop(columns = ['Sex'])

# %% [markdown]
# #### Make Dummy Variabel for Embarked And Drop Attribute Embarked

# %%
dummy_variable_2 = pd.get_dummies(df_titanic3['Embarked'])
dummy_variable_2.rename(columns={'C':'Embarked-C', 'Q':'Embarked-Q', 'S':'Embarked-S'}, inplace=True)
df_titanic3 = pd.concat([df_titanic3, dummy_variable_2], axis=1)
df_titanic3 = df_titanic3.drop(columns = ['Embarked'])

# %% [markdown]
# #### Feature Set

# %%
x = df_titanic3[['Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'Sex-female', 'Sex-male', 'Embarked-C', 'Embarked-Q', 'Embarked-S']]

# %%
y = df_titanic3['Survived'].values

# %% [markdown]
# #### Normalize Feature Set

# %%
x = preprocessing.StandardScaler().fit(x).transform(x.astype(float))

# %% [markdown]
# #### Split Train And Test in Feature Set

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split( x, y, test_size=0.2, random_state=4)
print ('Train set:', x_train.shape,  y_train.shape)
print ('Test set:', x_test.shape,  y_test.shape)
# Out:
# Train set: (712, 10) (712,)
# Test set: (179, 10) (179,)

# %% [markdown]
# ### Classification Modeling

# %% [markdown]
# #### From Data

# %%
plt.figure(figsize=(13, 5))
plt.suptitle('Persentase dan Perbandingan Penumpang Selamat dan Tidak Selamat Dari Data')

plt.subplot(1,2,1)
plt.pie(pd.DataFrame(y)[0].value_counts(), autopct='%1.1f%%', explode=[0,0.1])
plt.legend(['Not Survived','Survived'])

plt.subplot(1,2,2)
sns.countplot(y,label="Count")
plt.xticks([0,1], ['Not Survived','Survived'])

plt.show()

# %% [markdown]
# #### KNN

# %%
Ks = 10
mean_acc = np.zeros((Ks-1))
std_acc = np.zeros((Ks-1))
ConfustionMx = [];
for n in range(1,Ks):
    
    #Train Model and Predict  
    neigh = KNeighborsClassifier(n_neighbors = n).fit(x_train,y_train)
    y_knn=neigh.predict(x_test)
    mean_acc[n-1] = metrics.accuracy_score(y_test, y_knn)
    
    std_acc[n-1]=np.std(y_knn==y_test)/np.sqrt(y_knn.shape[0])

mean_acc
# Out:
# array([0.77653631, 0.81564246, 0.80446927, 0.82122905, 0.83240223,
#        0.83798883, 0.83240223, 0.83240223, 0.83240223])

# %%
plt.plot(range(1,Ks),mean_acc,'g')
plt.fill_between(range(1,Ks),mean_acc - 1 * std_acc,mean_acc + 1 * std_acc, alpha=0.10)
plt.legend(('Accuracy ', '+/- 3xstd'))
plt.ylabel('Accuracy ')
plt.xlabel('Number of Nabors (K)')
plt.tight_layout()
plt.show()

# %%
print( "The best accuracy was with", mean_acc.max(), "with k=", mean_acc.argmax()+1)
# Out:
# The best accuracy was with 0.8379888268156425 with k= 6

# %%
k = 6
neigh = KNeighborsClassifier(n_neighbors = k).fit(x_train,y_train)
y_knn = neigh.predict(x)
print("Accuracy: ", metrics.accuracy_score(y, y_knn))
print("Precision: ",metrics.precision_score(y, y_knn, average="macro"))
print("Recall: ",metrics.recall_score(y, y_knn, average="macro"))
print("F1-score: ",metrics.f1_score(y, y_knn, average="macro"))
# Out:
# Accuracy:  0.8428731762065096
# Precision:  0.8449160447761194
# Recall:  0.8190250215703192
# F1-score:  0.828125

# %%
plt.figure(figsize=(13, 5))
plt.suptitle('Persentase dan Perbandingan Penumpang Selamat dan Tidak Selamat Menggunakan KNN')

plt.subplot(1,2,1)
plt.pie(pd.DataFrame(y_knn)[0].value_counts(), autopct='%1.1f%%', explode=[0,0.1])
plt.legend(['Not Survived','Survived'])

plt.subplot(1,2,2)
sns.countplot(y_knn,label="Count")
plt.xticks([0,1], ['Not Survived','Survived'])

plt.show()

# %% [markdown]
# #### SVM

# %%
clf = svm.SVC(kernel='rbf')
clf.fit(x_train, y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
print("Train set Accuracy: ", metrics.accuracy_score(y_train, neigh.predict(x_train)))
# Out:
# Train set Accuracy:  0.8441011235955056

# %%
y_svm = clf.predict(x)
print("Accuracy: ", metrics.accuracy_score(y, y_svm))
print("Precision: ",metrics.precision_score(y, y_svm, average="macro"))
print("Recall: ",metrics.recall_score(y, y_svm, average="macro"))
print("F1-score: ",metrics.f1_score(y, y_svm, average="macro"))
# Out:
# Accuracy:  0.8417508417508418
# Precision:  0.8564085725858916
# Recall:  0.8092944108906146
# F1-score:  0.822709587830944

# %%
plt.figure(figsize=(13, 5))
plt.suptitle('Persentase dan Perbandingan Penumpang Selamat dan Tidak Selamat Menggunakan SVM')

plt.subplot(1,2,1)
plt.pie(pd.DataFrame(y_svm)[0].value_counts(), autopct='%1.1f%%', explode=[0,0.1])
plt.legend(['Not Survived','Survived'])

plt.subplot(1,2,2)
sns.countplot(y_svm,label="Count")
plt.xticks([0,1], ['Not Survived','Survived'])

plt.show()

# %% [markdown]
# ## Question 4

# %% [markdown]
# ### Preprocessing data

# %%
df_titanic4 = df_titanic

# %% [markdown]
# #### Feature Set

# %%
x = df_titanic4[['Pclass', 'Fare']]

# %% [markdown]
# #### Normalize Feature Set

# %%
x = preprocessing.StandardScaler().fit(x).transform(x.astype(float))

# %% [markdown]
# ### Clustering Modeling

# %% [markdown]
# #### K-Means

# %%
kmeans = KMeans(n_clusters=6)
kmeans.fit(x)
y_kmeans = kmeans.predict(x)

# %%
plt.figure(figsize=(13, 5))
plt.ylabel('Normalized Fare')
plt.xlabel('Normalized Pclass')
plt.title('Cluster for Pclass and Fare with K-Means')

plt.scatter(x[:, 0], x[:, 1], c=y_kmeans, s=50, cmap='viridis')

centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);

# %%
n_clusters_ = len(set(y_kmeans)) - (1 if -1 in y_kmeans else 0)
n_noise_ = list(y_kmeans).count(-1)

# %%
print('Estimated number of clusters: %d' % n_clusters_)
print('Estimated number of noise points: %d' % n_noise_)
print("Silhouette Coefficient: %0.3f"
      % metrics.silhouette_score(x, y_kmeans))
# Out:
# Estimated number of clusters: 6
# Estimated number of noise points: 0
# Silhouette Coefficient: 0.779

# %% [markdown]
# #### DBSCAN

# %%
dbscan = DBSCAN(eps=0.5, min_samples=3).fit(x)
core_samples_mask = np.zeros_like(dbscan.labels_, dtype=bool)
core_samples_mask[dbscan.core_sample_indices_] = True
y_dbscan = dbscan.labels_

n_clusters_ = len(set(y_dbscan)) - (1 if -1 in y_dbscan else 0)
n_noise_ = list(y_dbscan).count(-1)

# %%
plt.figure(figsize=(13, 5))
plt.ylabel('Normalized Fare')
plt.xlabel('Normalized Pclass')
plt.title('Cluster for Pclass and Fare with DBSCAN')

plt.scatter(x[:, 0], x[:, 1], c=y_dbscan, s=50, cmap='viridis')

# %%
print('Estimated number of clusters: %d' % n_clusters_)
print('Estimated number of noise points: %d' % n_noise_)
print("Silhouette Coefficient: %0.3f"
      % metrics.silhouette_score(x, y_dbscan))
# Out:
# Estimated number of clusters: 5
# Estimated number of noise points: 0
# Silhouette Coefficient: 0.747
