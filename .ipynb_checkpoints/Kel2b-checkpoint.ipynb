# %%
import statsmodels.api as sm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_titanic = pd.read_csv('train.csv')

# %%
df_titanic = df_titanic.drop(columns = ['PassengerId','Name','Ticket'])

# %%
df_titanic = df_titanic.drop(columns = ['Cabin'])

# %%
modus_embarked = df_titanic['Embarked'].value_counts().idxmax()
df_titanic['Embarked'].replace(np.nan, modus_embarked, inplace=True)

# %%
dummy_variable_1 = pd.get_dummies(df_titanic['Sex'])
dummy_variable_1.rename(columns={'female':'Sex-female', 'male':'Sex-male'}, inplace=True)
df_titanic = pd.concat([df_titanic, dummy_variable_1], axis=1)
df_titanic = df_titanic.drop(columns = ['Sex'])

# %%
dummy_variable_2 = pd.get_dummies(df_titanic['Embarked'])
dummy_variable_2.rename(columns={'C':'Embarked-C', 'Q':'Embarked-Q', 'S':'Embarked-S'}, inplace=True)
df_titanic = pd.concat([df_titanic, dummy_variable_2], axis=1)
df_titanic = df_titanic.drop(columns = ['Embarked'])

# %%
df_titanic['Age'].isnull()[1]
# Out:
# False

# %%
df_titanic_age = df_titanic.loc[~df_titanic['Age'].isnull()]

# %%
df_titanic_age.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Age           0
# SibSp         0
# Parch         0
# Fare          0
# Sex-female    0
# Sex-male      0
# Embarked-C    0
# Embarked-Q    0
# Embarked-S    0
# dtype: int64

# %%
df_titanic_nage = df_titanic.loc[df_titanic['Age'].isnull()]

# %%
df_titanic_nage.isnull().sum()
# Out:
# Survived        0
# Pclass          0
# Age           177
# SibSp           0
# Parch           0
# Fare            0
# Sex-female      0
# Sex-male        0
# Embarked-C      0
# Embarked-Q      0
# Embarked-S      0
# dtype: int64

# %%
df_titanic_age.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-9d3dd79afb9b> in <module>
# ----> 1 df_titanic_nage.isnull().sum()
#
# NameError: name 'df_titanic_nage' is not defined

# %%
df_titanic_age.columns
# Out:
# Index(['Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'Sex-female',
#        'Sex-male', 'Embarked-C', 'Embarked-Q', 'Embarked-S'],
#       dtype='object')

# %%
features = ['Survived', 'Pclass', 'SibSp', 'Parch', 'Fare', 'Sex-female',
            'Sex-male', 'Embarked-C', 'Embarked-Q', 'Embarked-S']
X = df_titanic_age[features]
y = df_titanic_age['Age']

# %%
X = sm.add_constant(X)
model = sm.OLS(y, X)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    Age   R-squared:                       0.275
# Model:                            OLS   Adj. R-squared:                  0.266
# Method:                 Least Squares   F-statistic:                     33.36
# Date:                Thu, 22 Oct 2020   Prob (F-statistic):           1.14e-44
# Time:                        21:10:53   Log-Likelihood:                -2808.7
# No. Observations:                 714   AIC:                             5635.
# Df Residuals:                     705   BIC:                             5676.
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         29.5617      1.211     24.416      0.000      27.185      31.939
# Survived      -6.7695      1.201     -5.639      0.000      -9.126      -4.412
# Pclass        -8.2088      0.716    -11.465      0.000      -9.614      -6.803
# SibSp         -4.0668      0.550     -7.389      0.000      -5.147      -2.986
# Parch         -0.8268      0.619     -1.335      0.182      -2.043       0.389
# Fare          -0.0122      0.011     -1.077      0.282      -0.034       0.010
# Sex-female    14.8952      0.936     15.912      0.000      13.057      16.733
# Sex-male      14.6665      0.748     19.614      0.000      13.198      16.135
# Embarked-C     7.8209      1.127      6.938      0.000       5.608      10.034
# Embarked-Q    12.1615      1.837      6.620      0.000       8.554      15.769
# Embarked-S     9.5793      0.874     10.966      0.000       7.864      11.294
# ==============================================================================
# Omnibus:                       21.453   Durbin-Watson:                   1.892
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               22.565
# Skew:                           0.423   Prob(JB):                     1.26e-05
# Kurtosis:                       3.209   Cond. No.                     4.08e+17
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.72e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
def pair_plot(df, col):
    pp = sns.pairplot(data=df,
                 palette='colorblind',
                 y_vars=['Age'],
                 x_vars=[col],
                 )
    pp.fig.set_size_inches(15,10)
    plt.show()

# %%
target_cols = ['Survived', 'Pclass', 'SibSp', 'Parch', 'Fare', 'Sex-female', 
               'Sex-male', 'Embarked-C', 'Embarked-Q', 'Embarked-S']
for c in target_cols:
    print('Pair Plot of {} with target'.format(c))
    pair_plot(df_titanic_age, c)
    print('='*110)
# Out:
# Pair Plot of Survived with target
# ==============================================================================================================
# Pair Plot of Pclass with target
# ==============================================================================================================
# Pair Plot of SibSp with target
# ==============================================================================================================
# Pair Plot of Parch with target
# ==============================================================================================================
# Pair Plot of Fare with target
# ==============================================================================================================
# Pair Plot of Sex-female with target
# ==============================================================================================================
# Pair Plot of Sex-male with target
# ==============================================================================================================
# Pair Plot of Embarked-C with target
# ==============================================================================================================
# Pair Plot of Embarked-Q with target
# ==============================================================================================================
# Pair Plot of Embarked-S with target
# ==============================================================================================================
