# %% [markdown]
# # Titanic: Machine Learning from Disaster

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# <i>Titanic: Machine Learning from Disaster</i> merupakan sebuah kompetisi <i>machine learning</i> legendaris di kaggle.com. Kompetisinya sangat sederhana, yaitu bagaimana menggunakan <i>machine learning</i> untuk membuat sebuah model yang dapat memprediksi penumpang yang selamat dalam tragedi Titanic.

# %% [markdown]
# Data yang diperlukan tersedia dalam https://www.kaggle.com/c/titanic/

# %% [markdown]
# ## 2. Import libraries

# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import NullFormatter
import pandas as pd
import numpy as np
import matplotlib.ticker as ticker
from sklearn import preprocessing
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ## 3. Read the data

# %%
df_titanic = pd.read_csv('train.csv')

# %%
df_titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## 4. Explore data

# %% [markdown]
# <table style="width:100%">
#     <tr>
#         <th>Variable</th>
#         <th>Definition</th>
#         <th>Key</th>
#     </tr>
#     <tr>
#         <th><code>Survived</code></th>
#         <th>Survival</th>
#         <th>0 = No, 1  = Yes</th>
#     </tr>
#     <tr>
#         <th><code>Pclass</code></th>
#         <th>Ticket Class</th>
#         <th>1 = 1st, 2 = 2nd, 3 = 3rd</th>
#     </tr>
#     <tr>
#         <th><code>Sex</code></th>
#         <th>Sex</th>
#         <th></th>
#     </tr>
#     <tr>
#         <th><code>Age</code></th>
#         <th>Age in years</th>
#         <th></th>
#     </tr>
#     <tr>
#         <th><code>SibSp</code></th>
#         <th># of siblings / spouses aboard the Titanic</th>
#         <th></th>
#     </tr>
#     <tr>
#         <th><code>Parch</code></th>
#         <th># of parents / children aboard the Titanic</th>
#         <th></th>
#     </tr>
#     <tr>
#         <th><code>Ticket</code></th>
#         <th>Ticket number</th>
#         <th></th>
#     </tr>
#     <tr>
#         <th><code>Fare</code></th>
#         <th>Passenger fare</th>
#         <th></th>
#     </tr>
#     <tr>
#         <th><code>Cabin</code></th>
#         <th>Cabin number</th>
#         <th></th>
#     </tr>
#     <tr>
#         <th><code>Embarked</code></th>
#         <th>Port of Embarkation</th>
#         <th>C = Cherbourg, Q = Queenstown, S = Southampton</th>
#     </tr>
# </table>

# %% [markdown]
# <ul>
#     <li><code>PassengerId</code>,nomor unik untuk masing-masing baris, tidak mempengaruhi target</li>
#     <li><code>Survived</code>,variabel target yang dicoba untuk diprediksi</li>
#         <ul>
#             <li>1 = Survived</li>
#             <li>0 = Not Survived</li>
#         </ul>
#     <li><code>Pclass</code> <i>(Passanger Class)</i>, mewakili status sosio-ekomoni penumpang (dikatagorikan dalam 3 level)</li>
#         <ul>
#             <li>1 = Kelas Atas</li>
#             <li>2 = Kelas Menengah</li>
#             <li>3 = Kelas Bawah</li>
#         </ul>
#     <li><code>Name</code>, nama penumpang</li>
#     <li><code>Sex</code>, jenis kelamin penumpang</li>
#     <li><code>Age</code>, umur penumpang (pecahan jika kurang dari 1; perkiraan jika dalam bentuk xx.5)</li>
#     <li><code>SibSp</code> <i>(Sibling/Spouse)</i>, jumlah saudara/pasangan penumpang dalam perjalanan</li>
#     <li><code>Parch</code> <i>(Parent/Children)</i>, jumlah orang tua/anak penumpang dalam perjalanan</li>
#     <li><code>Ticket</code>, nomor tiket penumpang</li>
#     <li><code>Fare</code>, tarif penumpang</li>
#     <li><code>Cabin</code>, nomor kabin penumpang</li>
#     <li><code>Embarked</code>, pelabuhan embarkasi penumpang, dituliskan dalam fitur katagorikal dengan 3 nilai unik (C, Q, dan S)</li>
#         <ul>
#             <li>C = Cherbourg</li>
#             <li>Q = Queenstown</li>
#             <li>S = Southampton</li>
#         </ul>
# </ul>

# %%
plt.figure(figsize=(13, 5))

plt.subplot(1,2,1)
plt.pie(df_titanic['Survived'].value_counts(), autopct='%1.1f%%', explode=[0,0.1])
plt.legend(['Not Survived','Survived'])

plt.subplot(1,2,2)
sns.countplot(df_titanic['Survived'],label="Count")

plt.show()

# %%
sns.countplot('Pclass',hue='Survived',data=df_titanic)
plt.legend(['Not Survived','Survived'])
plt.show()

# %%
sns.countplot('Sex',hue='Survived',data=df_titanic)
plt.legend(['Not Survived','Survived'])
plt.show()

# %%
plt.figure(figsize=(13, 5))

plt.subplot(1,2,1)
sns.distplot(df_titanic.loc[df_titanic['Survived'] == 0]['Age'])
sns.distplot(df_titanic.loc[df_titanic['Survived'] == 1]['Age'])
plt.legend(['Not Survived','Survived'])
plt.title('Survived Distribution in Age')

plt.subplot(1,2,2)
sns.boxplot(x = df_titanic['Survived'], y = df_titanic['Age'])
plt.title('Survived Distribution in Age')

plt.show()

# %%
sns.countplot('SibSp',hue='Survived',data=df_titanic)
plt.legend(['Not Survived','Survived'])
plt.show()

# %%
sns.countplot('Parch',hue='Survived',data=df_titanic)
plt.legend(['Not Survived','Survived'])
plt.show()

# %%
plt.figure(figsize=(13, 5))

plt.subplot(1,2,1)
sns.distplot(df_titanic.loc[df_titanic['Survived'] == 0]['Fare'])
sns.distplot(df_titanic.loc[df_titanic['Survived'] == 1]['Fare'])
plt.legend(['Not Survived','Survived'])
plt.title('Survived Distribution in Fare')

plt.subplot(1,2,2)
sns.boxplot(x = df_titanic['Survived'], y = df_titanic['Fare'])
plt.title('Survived Distribution in Fare')

plt.show()

# %%
sns.countplot('Embarked',hue='Survived',data=df_titanic)
plt.legend(['Not Survived','Survived'])
plt.show()

# %% [markdown]
# ## 3. Prepare Data

# %% [markdown]
# ### Drop Useless Features

# %%
df_titanic2 = df_titanic.drop(columns = ['PassengerId','Name','Ticket'])

# %%
df_titanic2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    object
#  3   Age       714 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Fare      891 non-null    float64
#  7   Cabin     204 non-null    object
#  8   Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %% [markdown]
# ### Missing Value

# %%
df_titanic2.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %% [markdown]
# #### Drop 'Cabin' column

# %%
df_titanic2 = df_titanic2.drop(columns = ['Cabin'])

# %% [markdown]
# #### Replace NaN in 'Age' column with it's mean

# %%
avg_age = df_titanic2['Age'].astype('float').mean()
df_titanic2['Age'].replace(np.nan, avg_age, inplace=True)

# %% [markdown]
# #### Replace NaN in 'Embarked' column with it's modus

# %%
modus_embarked = df_titanic2['Embarked'].value_counts().idxmax()
df_titanic2['Embarked'].replace(np.nan, modus_embarked, inplace=True)

# %%
df_titanic2.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %% [markdown]
# #### Change object-type

# %%
df_titanic2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    object
#  3   Age       891 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Fare      891 non-null    float64
#  7   Embarked  891 non-null    object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 55.8+ KB

# %%
dummy_variable_1 = pd.get_dummies(df_titanic2['Sex'])
dummy_variable_1.rename(columns={'female':'Sex-female', 'male':'Sex-male'}, inplace=True)
df_titanic2 = pd.concat([df_titanic2, dummy_variable_1], axis=1)
df_titanic2 = df_titanic2.drop(columns = ['Sex'])

# %%
dummy_variable_2 = pd.get_dummies(df_titanic2['Embarked'])
dummy_variable_2.rename(columns={'C':'Embarked-C', 'Q':'Embarked-Q', 'S':'Embarked-S'}, inplace=True)
df_titanic2 = pd.concat([df_titanic2, dummy_variable_2], axis=1)
df_titanic2 = df_titanic2.drop(columns = ['Embarked'])

# %%
df_titanic2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Survived    891 non-null    int64
#  1   Pclass      891 non-null    int64
#  2   Age         891 non-null    float64
#  3   SibSp       891 non-null    int64
#  4   Parch       891 non-null    int64
#  5   Fare        891 non-null    float64
#  6   Sex-female  891 non-null    uint8
#  7   Sex-male    891 non-null    uint8
#  8   Embarked-C  891 non-null    uint8
#  9   Embarked-Q  891 non-null    uint8
#  10  Embarked-S  891 non-null    uint8
# dtypes: float64(2), int64(4), uint8(5)
# memory usage: 46.2 KB

# %% [markdown]
# ## 2.REGRESSION

# %%
df_titanic2.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare  Sex-female  Sex-male  \
# 0         0       3  22.0      1      0   7.2500           0         1
# 1         1       1  38.0      1      0  71.2833           1         0
# 2         1       3  26.0      0      0   7.9250           1         0
# 3         1       1  35.0      1      0  53.1000           1         0
# 4         0       3  35.0      0      0   8.0500           0         1
#
#    Embarked-C  Embarked-Q  Embarked-S
# 0           0           0           1
# 1           1           0           0
# 2           0           0           1
# 3           0           0           1
# 4           0           0           1

# %%
def pair_plot(df, col):
    pp = sns.pairplot(data=df,
                 palette='colorblind',
                 y_vars=['Age'],
                 x_vars=[col],
                 )
    pp.fig.set_size_inches(15,10)
    plt.show()

# %%
target_cols = ['Survived', 'Pclass',  'SibSp', 'Parch', 'Fare',  'Sex-female', 'Sex-male', 'Embarked-C',
               'Embarked-Q', 'Embarked-S']
for c in target_cols:
    print('Pair Plot of {} with target'.format(c))
    pair_plot(df_titanic2, c)
    print('='*110)
# Out:
# Pair Plot of Survived with target
# ==============================================================================================================
# Pair Plot of Pclass with target
# ==============================================================================================================
# Pair Plot of SibSp with target
# ==============================================================================================================
# Pair Plot of Parch with target
# ==============================================================================================================
# Pair Plot of Fare with target
# ==============================================================================================================
# Pair Plot of Sex-female with target
# ==============================================================================================================
# Pair Plot of Sex-male with target
# ==============================================================================================================
# Pair Plot of Embarked-C with target
# ==============================================================================================================
# Pair Plot of Embarked-Q with target
# ==============================================================================================================
# Pair Plot of Embarked-S with target
# ==============================================================================================================

# %%
df_titanic2.corr(method='pearson').style.format("{:.2}").background_gradient(cmap=plt
                                                                         .get_cmap('coolwarm'), axis=1)
# Out:
# <style  type="text/css" >
#     #T_595d0444_146f_11eb_b80a_00e070576ce9row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_595d0444_146f_11eb_b80a_00e070576ce9row0_col1 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_595d0444_146f_11eb_b80a_00e070576ce9row0_col2 {
#             background-color:  #a1c0ff;
#             color:  #000000;
#         }    #T_595d0444_146f_11eb_b80a_00e070576ce9row0_col3 {
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }    #T_595d0444_146f_11eb_b80a_00e070576ce9row0_col4 {
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }    #T_595d0444_146f_11eb_b80a_00e070576ce9row0_col5 {
#             background-color:  #e1dad6;
#             color:  #000000;
#         }    #T_595d0444_146f_11eb_b80a_00e070576ce9row0_col6 {
#             background-color:  #f7aa8c;
#             color:  #000000;
#         }    #T_595d0444_146f_11eb_b80a_00e070576ce9row0_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_595d0444_146f_11eb_b80a_00e070576ce9row0_col8 {
#             background-color:  #d3dbe7;
#             color:  #000000;
#         }    #T_595d0444_146f_11eb_b80a_00e070576ce9row0_col9 {
#             background-color:  #b1cbfc;
#             color:  #000000;
#         }    #T_595d0444_146f_11eb_b80a_00e070576ce9row0_col10 {
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }    #T_595d0444_146f_11eb_b80a_00e070576ce9row1_col0 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_595d0444_146f_11eb_b80a_00e070576ce9row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_595d0444_146f_11eb_b80a_00e070576ce9row1_col2 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_595d0444_146f_11eb_b80a_00e070576ce9row1_col3 {
#             background-color:  #c3d5f4;
#             color:  #000000;
#         }    #T_595d0444_146f_11eb_b80a_00e070576ce9row1_col4 {
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }    #T_595d0444_146f_11eb_b80a_00e070576ce9row1_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_595d0444_146f_11eb_b80a_00e070576ce9row1_col6 {
#             background-color:  #93b5fe;
#             color:  #000000;
#         }    #T_595d0444_146f_11eb_b80a_00e070576ce9row1_col7 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }    #T_595d0444_146f_11eb_b80a_00e070576ce9row1_col8 {
#             background-color:  #7a9df8;
#             color:  #000000;
#         }    #T_595d0444_146f_11eb_b80a_00e070576ce9row1_col9 {
#             background-color:  #dcdddd;
#             color:  #000000;
#         }    #T_595d0444_146f_11eb_b80a_00e070576ce9row1_col10 {
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }    #T_595d0444_146f_11eb_b80a_00e070576ce9row2_col0 {
#             background-color:  #7a9df8;
#             color:  #000000;
#         }    #T_595d0444_146f_11eb_b80a_00e070576ce9row2_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_595d0444_146f_11eb_b80a_00e070576ce9row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_595d0444_146f_11eb_b80a_00e070576ce9row2_col3 {
#             background-color:  #506bda;
#             color:  #000000;
#         }    #T_595d0444_146f_11eb_b80a_00e070576ce9row2_col4 {
#             background-color:  #5e7de7;
#             color:  #000000;
#         }    #T_595d0444_146f_11eb_b80a_00e070576ce9row2_col5 {
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }    #T_595d0444_146f_11eb_b80a_00e070576ce9row2_col6 {
#             background-color:  #7699f6;
#             color:  #000000;
#         }    #T_595d0444_146f_11eb_b80a_00e070576ce9row2_col7 {
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }    #T_595d0444_146f_11eb_b80a_00e070576ce9row2_col8 {
#             background-color:  #94b6ff;
#             color:  #000000;
#         }    #T_595d0444_146f_11eb_b80a_00e070576ce9row2_col9 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_595d0444_146f_11eb_b80a_00e070576ce9row2_col10 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_595d0444_146f_11eb_b80a_00e070576ce9row3_col0 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_595d0444_146f_11eb_b80a_00e070576ce9row3_col1 {
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }    #T_595d0444_146f_11eb_b80a_00e070576ce9row3_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_595d0444_146f_11eb_b80a_00e070576ce9row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_595d0444_146f_11eb_b80a_00e070576ce9row3_col4 {
#             background-color:  #e3d9d3;
#             color:  #000000;
#         }    #T_595d0444_146f_11eb_b80a_00e070576ce9row3_col5 {
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }    #T_595d0444_146f_11eb_b80a_00e070576ce9row3_col6 {
#             background-color:  #98b9ff;
#             color:  #000000;
#         }    #T_595d0444_146f_11eb_b80a_00e070576ce9row3_col7 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_595d0444_146f_11eb_b80a_00e070576ce9row3_col8 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_595d0444_146f_11eb_b80a_00e070576ce9row3_col9 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_595d0444_146f_11eb_b80a_00e070576ce9row3_col10 {
#             background-color:  #8badfd;
#             color:  #000000;
#         }    #T_595d0444_146f_11eb_b80a_00e070576ce9row4_col0 {
#             background-color:  #92b4fe;
#             color:  #000000;
#         }    #T_595d0444_146f_11eb_b80a_00e070576ce9row4_col1 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_595d0444_146f_11eb_b80a_00e070576ce9row4_col2 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_595d0444_146f_11eb_b80a_00e070576ce9row4_col3 {
#             background-color:  #e4d9d2;
#             color:  #000000;
#         }    #T_595d0444_146f_11eb_b80a_00e070576ce9row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_595d0444_146f_11eb_b80a_00e070576ce9row4_col5 {
#             background-color:  #b6cefa;
#             color:  #000000;
#         }    #T_595d0444_146f_11eb_b80a_00e070576ce9row4_col6 {
#             background-color:  #bed2f6;
#             color:  #000000;
#         }    #T_595d0444_146f_11eb_b80a_00e070576ce9row4_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_595d0444_146f_11eb_b80a_00e070576ce9row4_col8 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_595d0444_146f_11eb_b80a_00e070576ce9row4_col9 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_595d0444_146f_11eb_b80a_00e070576ce9row4_col10 {
#             background-color:  #8badfd;
#             color:  #000000;
#         }    #T_595d0444_146f_11eb_b80a_00e070576ce9row5_col0 {
#             background-color:  #e2dad5;
#             color:  #000000;
#         }    #T_595d0444_146f_11eb_b80a_00e070576ce9row5_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_595d0444_146f_11eb_b80a_00e070576ce9row5_col2 {
#             background-color:  #c4d5f3;
#             color:  #000000;
#         }    #T_595d0444_146f_11eb_b80a_00e070576ce9row5_col3 {
#             background-color:  #d2dbe8;
#             color:  #000000;
#         }    #T_595d0444_146f_11eb_b80a_00e070576ce9row5_col4 {
#             background-color:  #dbdcde;
#             color:  #000000

# %%
features = ['Survived', 'Pclass', 'SibSp', 'Parch', 'Fare',  'Sex-female', 'Sex-male', 'Embarked-C',
               'Embarked-Q', 'Embarked-S']
X = df_titanic2[features]
y = df_titanic2['Age']

# %%
import statsmodels.api as sm

# %%
X = sm.add_constant(X)
model = sm.OLS(y, X)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    Age   R-squared:                       0.202
# Model:                            OLS   Adj. R-squared:                  0.194
# Method:                 Least Squares   F-statistic:                     27.84
# Date:                Thu, 22 Oct 2020   Prob (F-statistic):           9.11e-39
# Time:                        21:03:27   Log-Likelihood:                -3449.0
# No. Observations:                 891   AIC:                             6916.
# Df Residuals:                     882   BIC:                             6959.
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         26.9114      1.014     26.534      0.000      24.921      28.902
# Survived      -5.5485      1.019     -5.443      0.000      -7.549      -3.548
# Pclass        -6.5551      0.608    -10.777      0.000      -7.749      -5.361
# SibSp         -2.0089      0.398     -5.044      0.000      -2.791      -1.227
# Parch         -1.2317      0.559     -2.204      0.028      -2.329      -0.135
# Fare          -0.0079      0.010     -0.784      0.433      -0.028       0.012
# Sex-female    13.6593      0.796     17.169      0.000      12.098      15.221
# Sex-male      13.2521      0.628     21.088      0.000      12.019      14.485
# Embarked-C     7.3624      0.838      8.786      0.000       5.718       9.007
# Embarked-Q    11.1653      1.143      9.771      0.000       8.923      13.408
# Embarked-S     8.3836      0.614     13.664      0.000       7.179       9.588
# ==============================================================================
# Omnibus:                       40.585   Durbin-Watson:                   1.952
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               47.141
# Skew:                           0.487   Prob(JB):                     5.80e-11
# Kurtosis:                       3.567   Cond. No.                     7.54e+17
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 5.49e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# ## 4. Data Modeling

# %% [markdown]
# ### Classification

# %% [markdown]
# #### Feature set

# %%
df_titanic2.columns
# Out:
# Index(['Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'Sex-female',
#        'Sex-male', 'Embarked-C', 'Embarked-Q', 'Embarked-S'],
#       dtype='object')

# %%
x = df_titanic2[['Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'Sex-female', 'Sex-male', 'Embarked-C', 'Embarked-Q', 'Embarked-S']]

# %%
y = df_titanic2['Survived'].values

# %% [markdown]
# #### Normalize Data

# %%
x = preprocessing.StandardScaler().fit(x).transform(x.astype(float))

# %% [markdown]
# #### Split Data Set

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split( x, y, test_size=0.2, random_state=4)
print ('Train set:', x_train.shape,  y_train.shape)
print ('Test set:', x_test.shape,  y_test.shape)
# Out:
# Train set: (712, 10) (712,)
# Test set: (179, 10) (179,)

# %% [markdown]
# #### KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics

# %%
Ks = 10
mean_acc = np.zeros((Ks-1))
std_acc = np.zeros((Ks-1))
ConfustionMx = [];
for n in range(1,Ks):
    
    #Train Model and Predict  
    neigh = KNeighborsClassifier(n_neighbors = n).fit(x_train,y_train)
    y_knn=neigh.predict(x_test)
    mean_acc[n-1] = metrics.accuracy_score(y_test, y_knn)
    
    std_acc[n-1]=np.std(y_knn==y_test)/np.sqrt(y_knn.shape[0])

mean_acc
# Out:
# array([0.77653631, 0.81564246, 0.80446927, 0.82122905, 0.83240223,
#        0.83798883, 0.83240223, 0.83240223, 0.83240223])

# %%
plt.plot(range(1,Ks),mean_acc,'g')
plt.fill_between(range(1,Ks),mean_acc - 1 * std_acc,mean_acc + 1 * std_acc, alpha=0.10)
plt.legend(('Accuracy ', '+/- 3xstd'))
plt.ylabel('Accuracy ')
plt.xlabel('Number of Nabors (K)')
plt.tight_layout()
plt.show()

# %%
print( "The best accuracy was with", mean_acc.max(), "with k=", mean_acc.argmax()+1)
# Out:
# The best accuracy was with 0.8379888268156425 with k= 6

# %%
k = 6
neigh = KNeighborsClassifier(n_neighbors = k).fit(x_train,y_train)
y_knn = neigh.predict(x_test)
print("Train set Accuracy: ", metrics.accuracy_score(y_train, neigh.predict(x_train)))
print("Test set Accuracy: ", metrics.accuracy_score(y_test, y_knn))
print("Train set Precision: ",metrics.precision_score(y_train, neigh.predict(x_train), average="macro"))
print("Test set Precision: ",metrics.precision_score(y_test, y_knn, average="macro"))
print("Train set Recall: ",metrics.recall_score(y_train, neigh.predict(x_train), average="macro"))
print("Test set Recall: ",metrics.recall_score(y_test, y_knn, average="macro"))
print("Train set F1-score: ",metrics.f1_score(y_train, neigh.predict(x_train), average="macro"))
print("Test set F1-score: ",metrics.f1_score(y_test, y_knn, average="macro"))
# Out:
# Train set Accuracy:  0.8441011235955056
# Test set Accuracy:  0.8379888268156425
# Train set Precision:  0.8474749440498199
# Test set Precision:  0.8312401883830456
# Train set Recall:  0.8239402935840343
# Test set Recall:  0.7955182072829132
# Train set F1-score:  0.8320122942718131
# Test set F1-score:  0.8087395453373125

# %% [markdown]
# #### SVM

# %%
from sklearn import svm
clf = svm.SVC(kernel='rbf')
clf.fit(x_train, y_train)
# Out:
# SVC()

# %%
y_svm = clf.predict(x_test)
y_svm [0:5]
# Out:
# array([0, 0, 1, 1, 0], dtype=int64)

# %%
print("Train set Accuracy: ", metrics.accuracy_score(y_train, neigh.predict(x_train)))
print("Test set Accuracy: ", metrics.accuracy_score(y_test, y_svm))
print("Train set Precision: ",metrics.precision_score(y_train, neigh.predict(x_train), average="macro"))
print("Test set Precision: ",metrics.precision_score(y_test, y_svm, average="macro"))
print("Train set Recall: ",metrics.recall_score(y_train, neigh.predict(x_train), average="macro"))
print("Test set Recall: ",metrics.recall_score(y_test, y_svm, average="macro"))
print("Train set F1-score: ",metrics.f1_score(y_train, neigh.predict(x_train), average="macro"))
print("Test set F1-score: ",metrics.f1_score(y_test, y_svm, average="macro"))
# Out:
# Train set Accuracy:  0.8441011235955056
# Test set Accuracy:  0.8547486033519553
# Train set Precision:  0.8474749440498199
# Test set Precision:  0.8595946387708402
# Train set Recall:  0.8239402935840343
# Test set Recall:  0.8081232492997199
# Train set F1-score:  0.8320122942718131
# Test set F1-score:  0.8257711889787361

# %% [markdown]
# ### Clustering

# %%
plt.figure(figsize=(13, 5))

plt.subplot(1,2,1)
sns.distplot(df_titanic.loc[df_titanic['Pclass'] == 1]['Fare'])
sns.distplot(df_titanic.loc[df_titanic['Pclass'] == 2]['Fare'])
sns.distplot(df_titanic.loc[df_titanic['Pclass'] == 3]['Fare'])
plt.legend(['Not Survived','Survived'])
plt.title('Survived Distribution in Fare')

plt.subplot(1,2,2)
sns.boxplot(x = df_titanic['Pclass'], y = df_titanic['Fare'])
plt.title('Survived Distribution in Fare')

plt.show()

# %% [markdown]
# #### Feature set

# %%
x = df_titanic2[['Pclass', 'Fare']]

# %% [markdown]
# #### Normalize Data

# %%
x = preprocessing.StandardScaler().fit(x).transform(x.astype(float))

# %% [markdown]
# #### K-Means

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=6)
kmeans.fit(x)
y_kmeans = kmeans.predict(x)

# %%
plt.figure(figsize=(13, 5))

plt.scatter(x[:, 0], x[:, 1], c=y_kmeans, s=50, cmap='viridis')

centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);

# %% [markdown]
# #### K-DBS

# %%
df_titanic['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
from sklearn.cluster import DBSCAN
dbscan = DBSCAN(eps=0.75, min_samples=5).fit(x)
core_samples_mask = np.zeros_like(dbscan.labels_, dtype=bool)
core_samples_mask[dbscan.core_sample_indices_] = True
labels = dbscan.labels_

n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
n_noise_ = list(labels).count(-1)

# %%
print('Estimated number of clusters: %d' % n_clusters_)
print('Estimated number of noise points: %d' % n_noise_)
print("Silhouette Coefficient: %0.3f"
      % metrics.silhouette_score(x, labels))
# Out:
# Estimated number of clusters: 4
# Estimated number of noise points: 3
# Silhouette Coefficient: 0.747

# %%
import matplotlib.pyplot as plt

# Black removed and is used for noise instead.
unique_labels = set(labels)
colors = [plt.cm.Spectral(each)
          for each in np.linspace(0, 1, len(unique_labels))]
for k, col in zip(unique_labels, colors):
    if k == -1:
        # Black used for noise.
        col = [0, 0, 0, 1]

    class_member_mask = (labels == k)

    xy = x[class_member_mask & core_samples_mask]
    plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=tuple(col),
             markeredgecolor='k', markersize=14)

    xy = x[class_member_mask & ~core_samples_mask]
    plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=tuple(col),
             markeredgecolor='k', markersize=6)

plt.title('Estimated number of clusters: %d' % n_clusters_)
plt.show()

# %%
df_titanic['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64
