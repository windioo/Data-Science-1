# %%
import numpy as np  # useful for many scientific computing in Python
import pandas as pd # primary data structure library

# %%
# !conda install -c conda-forge folium=0.5.0 --yes
import folium

print('Folium installed and imported!')
# Out:
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(139): Could not remove or rename C:\Users\User\anaconda3\pkgs\openssl-1.1.1g-he774522_0.tar.bz2.  Please remove this file manually (you may need to reboot to free file handles)
#
# InvalidArchiveError('Error with archive C:\\Users\\User\\anaconda3\\pkgs\\openssl-1.1.1g-he774522_0.tar.bz2.  You probably need to delete and re-download or re-create this file.  Message from libarchive was:\n\nCould not unlink')
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working...
# Warning: 4 possible package resolutions (only showing differing packages):
#   - anaconda/win-64::ca-certificates-2020.6.24-0, anaconda/win-64::certifi-2020.6.20-py38_0
#   - anaconda/win-64::ca-certificates-2020.6.24-0, defaults/win-64::certifi-2020.6.20-py38_0
#   - anaconda/win-64::certifi-2020.6.20-py38_0, defaults/win-64::ca-certificates-2020.6.24-0
#   - defaults/win-64::ca-certificates-2020.6.24-0, defaults/win-64::certifi-2020.6.20-py38_0done
#
# ## Package Plan ##
#
#   environment location: C:\Users\User\anaconda3
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     branca-0.4.1               |             py_0          26 KB  conda-forge
#     conda-4.8.5                |   py38h32f6830_1         3.1 MB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     openssl-1.1.1g             |       he774522_0         5.7 MB  conda-forge
#     python_abi-3.8             |           1_cp38           4 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         9.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   altair             conda-forge/noarch::altair-4.1.0-py_1
#   branca             conda-forge/noarch::branca-0.4.1-py_0
#   folium             conda-forge/noarch::folium-0.5.0-py_0
#   python_abi         conda-forge/win-64::python_abi-3.8-1_cp38
#   vincent            conda-forge/noarch::vincent-0.4.4-py_1
#
# The following packages will be UPDATED:
#
#   conda                        anaconda::conda-4.8.5-py38_0 --> conda-forge::conda-4.8.5-py38h32f6830_1
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   openssl                                          anaconda --> conda-forge
#
#
#
# Downloading and Extracting Packages
#
# branca-0.4.1         | 26 KB     |            |   0%
# branca-0.4.1         | 26 KB     | ######1    |  62%
# branca-0.4.1         | 26 KB     | ########## | 100%
#
# openssl-1.1.1g       | 5.7 MB    |            |   0%
# openssl-1.1.1g       | 5.7 MB    | 1          |   1%
# openssl-1.1.1g       | 5.7 MB    | 4          |   4%
# openssl-1.1.1g       | 5.7 MB    | 7          |   7%
# openssl-1.1.1g       | 5.7 MB    | #          |  10%
# openssl-1.1.1g       | 5.7 MB    | #2         |  13%
# openssl-1.1.1g       | 5.7 MB    | #5         |  15%
# openssl-1.1.1g       | 5.7 MB    | #7         |  18%
# openssl-1.1.1g       | 5.7 MB    | ##         |  20%
# openssl-1.1.1g       | 5.7 MB    | ##2        |  23%
# openssl-1.1.1g       | 5.7 MB    | ##5        |  25%
# openssl-1.1.1g       | 5.7 MB    | ##7        |  28%
# openssl-1.1.1g       | 5.7 MB    | ##9        |  30%
# openssl-1.1.1g       | 5.7 MB    | ###1       |  32%
# openssl-1.1.1g       | 5.7 MB    | ###3       |  34%
# openssl-1.1.1g       | 5.7 MB    | ###5       |  36%
# openssl-1.1.1g       | 5.7 MB    | ###7       |  38%
# openssl-1.1.1g       | 5.7 MB    | ####       |  40%
# openssl-1.1.1g       | 5.7 MB    | ####2      |  42%
# openssl-1.1.1g       | 5.7 MB    | ####4      |  44%
# openssl-1.1.1g       | 5.7 MB    | ####6      |  46%
# openssl-1.1.1g       | 5.7 MB    | ####8      |  49%
# openssl-1.1.1g       | 5.7 MB    | #####      |  51%
# openssl-1.1.1g       | 5.7 MB    | #####2     |  53%
# openssl-1.1.1g       | 5.7 MB    | #####5     |  55%
# openssl-1.1.1g       | 5.7 MB    | #####7     |  57%
# openssl-1.1.1g       | 5.7 MB    | #####9     |  59%
# openssl-1.1.1g       | 5.7 MB    | ######1    |  62%
# openssl-1.1.1g       | 5.7 MB    | ######3    |  64%
# openssl-1.1.1g       | 5.7 MB    | ######5    |  66%
# openssl-1.1.1g       | 5.7 MB    | ######7    |  68%
# openssl-1.1.1g       | 5.7 MB    | ######9    |  70%
# openssl-1.1.1g       | 5.7 MB    | #######1   |  72%
# openssl-1.1.1g       | 5.7 MB    | #######3   |  74%
# openssl-1.1.1g       | 5.7 MB    | #######5   |  76%
# openssl-1.1.1g       | 5.7 MB    | #######7   |  78%
# openssl-1.1.1g       | 5.7 MB    | ########   |  80%
# openssl-1.1.1g       | 5.7 MB    | ########2  |  82%
# openssl-1.1.1g       | 5.7 MB    | ########4  |  85%
# openssl-1.1.1g       | 5.7 MB    | ########6  |  86%
# openssl-1.1.1g       | 5.7 MB    | ########8  |  88%
# openssl-1.1.1g       | 5.7 MB    | #########  |  90%
# openssl-1.1.1g       | 5.7 MB    | #########2 |  92%
# openssl-1.1.1g       | 5.7 MB    | #########4 |  95%
# openssl-1.1.1g       | 5.7 MB    | #########6 |  97%
# openssl-1.1.1g       | 5.7 MB    | #########8 |  99%
# openssl-1.1.1g       | 5.7 MB    | ########## | 100%
#
# folium-0.5.0         | 45 KB     |            |   0%
# folium-0.5.0         | 45 KB     | ########## | 100%
# folium-0.5.0         | 45 KB     | ########## | 100%
#
# python_abi-3.8       | 4 KB      |            |   0%
# python_abi-3.8       | 4 KB      | ########## | 100%
# python_abi-3.8       | 4 KB      | ########## | 100%
#
# conda-4.8.5          | 3.1 MB    |            |   0%
# conda-4.8.5          | 3.1 MB    | 1          |   1%
# conda-4.8.5          | 3.1 MB    | 5          |   5%
# conda-4.8.5          | 3.1 MB    | 9          |   9%
# conda-4.8.5          | 3.1 MB    | #3         |  13%
# conda-4.8.5          | 3.1 MB    | #8         |  18%
# conda-4.8.5          | 3.1 MB    | ##2        |  23%
# conda-4.8.5          | 3.1 MB    | ##6        |  27%
# conda-4.8.5          | 3.1 MB    | ###1       |  32%
# conda-4.8.5          | 3.1 MB    | ###5       |  36%
# conda-4.8.5          | 3.1 MB    | ####       |  41%
# conda-4.8.5          | 3.1 MB    | ####5      |  45%
# conda-4.8.5          | 3.1 MB    | #####      |  50%
# conda-4.8.5          | 3.1 MB    | #####4     |  54%
# conda-4.8.5          | 3.1 MB    | #####8     |  58%
# conda-4.8.5          | 3.1 MB    | ######1    |  61%
# conda-4.8.5          | 3.1 MB    | ######3    |  64%
# conda-4.8.5          | 3.1 MB    | ######5    |  66%
# conda-4.8.5          | 3.1 MB    | ######7    |  68%
# conda-4.8.5          | 3.1 MB    | #######    |  71%
# conda-4.8.5          | 3.1 MB    | #######2   |  73%
# conda-4.8.5          | 3.1 MB    | #######4   |  75%
# conda-4.8.5          | 3.1 MB    | #######6   |  77%
# conda-4.8.5          | 3.1 MB    | #######8   |  79%
# conda-4.8.5          | 3.1 MB    | ########3  |  84%
# conda-4.8.5          | 3.1 MB    | ########7  |  88%
# conda-4.8.5          | 3.1 MB    | #########1 |  92%
# conda-4.8.5          | 3.1 MB    | #########5 |  96%
# conda-4.8.5          | 3.1 MB    | #########9 |  99%
# conda-4.8.5          | 3.1 MB    | ########## | 100%
#
# vincent-0.4.4        | 28 KB     |            |   0%
# vincent-0.4.4        | 28 KB     | #####7     |  58%
# vincent-0.4.4        | 28 KB     | ########## | 100%
#
# altair-4.1.0         | 614 KB    |            |   0%
# altair-4.1.0         | 614 KB    | 2          |   3%
# altair-4.1.0         | 614 KB    | ###3       |  34%
# altair-4.1.0         | 614 KB    | #####9     |  60%
# altair-4.1.0         | 614 KB    | #########1 |  91%
# altair-4.1.0         | 614 KB    | ########## | 100%
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working...
# Warning: 4 possible package resolutions (only showing differing packages):
#   - anaconda/win-64::ca-certificates-2020.6.24-0, anaconda/win-64::certifi-2020.6.20-py38_0
#   - anaconda/win-64::certifi-2020.6.20-py38_0, defaults/win-64::ca-certificates-2020.6.24-0
#   - anaconda/win-64::ca-certificates-2020.6.24-0, defaults/win-64::certifi-2020.6.20-py38_0
#   - defaults/win-64::ca-certificates-2020.6.24-0, defaults/win-64::certifi-2020.6.20-py38_0done
#
# ## Package Plan ##
#
#   environment location: C:\Users\User\anaconda3
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     openssl-1.1.1g             |       he774522_0         5.7 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         5.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   altair             conda-forge/noarch::altair-4.1.0-py_1
#   branca             conda-forge/noarch::branca-0.4.1-py_0
#   folium             conda-forge/noarch::folium-0.5.0-py_0
#   python_abi         conda-forge/win-64::python_abi-3.8-1_cp38
#   vincent            conda-forge/noarch::vincent-0.4.4-py_1
#
# The following packages will be UPDATED:
#
#   conda                        anaconda::conda-4.8.5-py38_0 --> conda-forge::conda-4.8.5-py38h32f6830_1
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   openssl                                          anaconda --> conda-forge
#
#
#
# Downloading and Extracting Packages
#
# openssl-1.1.1g       | 5.7 MB    |            |   0%
# openssl-1.1.1g       | 5.7 MB    |            |   0%
# openssl-1.1.1g       | 5.7 MB    |            |   1%
# openssl-1.1.1g       | 5.7 MB    | 3          |   4%
# openssl-1.1.1g       | 5.7 MB    | 6          |   6%
# openssl-1.1.1g       | 5.7 MB    | #          |  11%
# openssl-1.1.1g       | 5.7 MB    | #4         |  15%
# openssl-1.1.1g       | 5.7 MB    | #9         |  19%
# openssl-1.1.1g       | 5.7 MB    | ##3        |  23%
# openssl-1.1.1g       | 5.7 MB    | ##6        |  27%
# openssl-1.1.1g       | 5.7 MB    | ###1       |  31%
# openssl-1.1.1g       | 5.7 MB    | ###4       |  35%
# openssl-1.1.1g       | 5.7 MB    | ###9       |  39%
# openssl-1.1.1g       | 5.7 MB    | ####3      |  44%
# openssl-1.1.1g       | 5.7 MB    | ####7      |  48%
# openssl-1.1.1g       | 5.7 MB    | #####2     |  52%
# openssl-1.1.1g       | 5.7 MB    | #####6     |  57%
# openssl-1.1.1g       | 5.7 MB    | ######1    |  61%
# openssl-1.1.1g       | 5.7 MB    | ######5    |  66%
# openssl-1.1.1g       | 5.7 MB    | #######    |  70%
# openssl-1.1.1g       | 5.7 MB    | #######4   |  74%
# openssl-1.1.1g       | 5.7 MB    | #######8   |  79%
# openssl-1.1.1g       | 5.7 MB    | ########3  |  83%
# openssl-1.1.1g       | 5.7 MB    | ########7  |  88%
# openssl-1.1.1g       | 5.7 MB    | #########1 |  92%
# openssl-1.1.1g       | 5.7 MB    | #########5 |  96%
# openssl-1.1.1g       | 5.7 MB    | ########## | 100%
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(139): Could not remove or rename C:\Users\User\anaconda3\pkgs\openssl-1.1.1g-he774522_0.tar.bz2.  Please remove this file manually (you may need to reboot to free file handles)
#
# InvalidArchiveError('Error with archive C:\\Users\\User\\anaconda3\\pkgs\\openssl-1.1.1g-he774522_0.tar.bz2.  You probably need to delete and re-download or re-create this file.  Message from libarchive was:\n\nCould not unlink')
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-4df4df2c5b32> in <module>
#       1 get_ipython().system('conda install -c conda-forge folium=0.5.0 --yes')
# ----> 2 import folium
#       3
#       4 print('Folium installed and imported!')
#
# ModuleNotFoundError: No module named 'folium'

# %%
# define the world map
world_map = folium.Map()

# display world map
world_map
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-db402cb52afc> in <module>
#       1 # define the world map
# ----> 2 world_map = folium.Map()
#       3
#       4 # display world map
#       5 world_map
#
# NameError: name 'folium' is not defined
